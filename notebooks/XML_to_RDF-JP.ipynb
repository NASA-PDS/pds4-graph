# %%
import xml.etree.ElementTree as ET
import requests
import uuid
import re
import os

from rdflib import Graph


from urllib.parse import urlparse

# TODO: Get these from the ttl file
TYPE = "rdf:type"
PDS4_TYPE = "pds4:"

# %%
r = requests.get('https://pds-en-registry-graph.cluster-cibj64l3k87g.us-west-2.neptune.amazonaws.com:8182/sparql')
r.status_code
# Out:
# 403

# %%
# Connect to Neptune Database
protocol = 'https'

# TODO: Use config file to access credentials 
access_key = os.getenv('AWS_ACCESS_KEY_ID', '')
secret_key = os.getenv('AWS_SECRET_ACCESS_KEY', '')
region = os.getenv('SERVICE_REGION', '')
print(region)

# %%
graph = Graph()
graph.parse('PDS4_PDS_RDFTTL_1H00.ttl', format='ttl')
# Out:
# <Graph identifier=N0c1a5722c24541b0bd3594e534217b79 (<class 'rdflib.graph.Graph'>)>

# %%
# Get class identifier
temp = "product_bundle"
q = 'SELECT ?s WHERE {filter contains(?s, ?variable)}'
results = graph.query(q, initBindings={'variable': rdflib.URIRef(temp)})

# %%
for row in results:
    print(row)

# %%
for s, p, o in graph:
    print(s, p, o)
# Out:
# http://ontology.pds.nasa.gov/taxonomy/urn:nasa:pds:0001_nasa_pds_1:all:user:cart:cylindrical::1.0 http://www.w3.org/2000/01/rdf-schema#comment This is an in-situ projection used for (non-stereo) panoramas. Each image row represents a constant elevation and each image column represents a constant azimuth, from a given point of view. The image scale in degrees per pixel is constant across the image.
# http://ontology.pds.nasa.gov/taxonomy/urn:nasa:pds:0001_nasa_pds_1:pds:tndo_context:pds:target:dwarf_planet::1.0 http://www.w3.org/2000/01/rdf-schema#label Dwarf Planet
# http://ontology.pds.nasa.gov/taxonomy/urn:nasa:pds:0001_nasa_pds_1:all:user:img:device_currents::1.0 http://www.w3.org/2000/01/rdf-schema#label Device_Currents
# http://ontology.pds.nasa.gov/taxonomy/urn:nasa:pds:0001_nasa_pds_1:all:user:img:imaging::focus_stack::1.0 http://www.w3.org/2000/01/rdf-schema#label Focus_Stack
# ...

# %%
def createUniqueID():
    return uuid.uuid4()

# %%
def get_im_object_id(label):
    return id # pds4:urn:nasa:pds:0001_nasa_pds_1:pds:product_components:pds:identification_area::1.0

# %%
def getText(tag):
    text = re.findall(r'}(\w+)', tag)
    return text

# %%
tree = ET.fromstring(requests.get('https://pds-imaging.jpl.nasa.gov/data/nsyt/insight_cameras/bundle.xml').text)

# %%
path = urlparse('https://pds-imaging.jpl.nasa.gov/data/nsyt/insight_cameras/bundle.xml').path
path = path.replace('/', '_')
path = path.replace('.xml', '.rdf')
path = path[1:]

rdf_file = open(path, "a")

# %%
# TODO: Get correct classes and subclasses with indents
# Has to go through all product first before outputting
for elem in tree.iter():
    uniqueId = createUniqueID()
    
    # Get Classes
    if elem.text.isspace():
        text = getText(elem.tag)
        print(str(uniqueId) + ' ' + TYPE + ' ' + text[0])
    
    # Get subclasses
    else:
        text = getText(elem.tag)
        print("\t\t\t\t" + PDS4_TYPE + text[0] + ' ' + elem.text)
# Out:
# 507eedde-e50a-4197-914e-0521e6aeb87b rdf:type Product_Bundle
# 9e852e85-92a2-465f-8c0d-d8c883584d0a rdf:type Identification_Area
# 				pds4:logical_identifier urn:nasa:pds:insight_cameras
# 				pds4:version_id 1.0
# 				pds4:title InSightCamerasBundle
# 				pds4:information_model_version 1.11.1.0
# 				pds4:product_class Product_Bundle
# 9e3634ac-296a-4019-a1b2-3f338c9e73c6 rdf:type Citation_Information
# 				pds4:author_list R.Deen,H.Abarca,P.Zamani,J.Maki
# 				pds4:publication_year 2019
# 				pds4:description
# 		InSightCamerasExperimentDataRecord(EDR)andReducedDataRecord(RDR)DataProducts
#
# 98cfdb94-c1ab-4d85-a077-47a7634968d2 rdf:type Context_Area
# 				pds4:comment ObservationalIntent
# 2c0a7f20-e72e-4b58-bd37-4b13cd677a65 rdf:type Time_Coordinates
# 				pds4:start_date_time 2019-10-02T04:36:06.728Z
# 				pds4:stop_date_time 2020-01-01T14:57:01.214Z
# 1cd2fe62-55ef-416b-bfb2-0e3b509b4caf rdf:type Primary_Result_Summary
# 				pds4:purpose Science
# ...
